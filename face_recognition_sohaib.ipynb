# %%
# !pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#      |████████████████████████████████| 100.1 MB 23 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=c3681a2a0d5c806c88965eca0472b742b1a700c70d38cce9b20f6817fe4ff149
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import face_recognition

# %%
# !wget https://raw.githubusercontent.com/sohaib-nasir/face_recognition_python/master/m1.jpg
# !wget https://raw.githubusercontent.com/sohaib-nasir/face_recognition_python/master/m2.jpg
# Out:
# --2022-06-16 07:09:28--  https://raw.githubusercontent.com/sohaib-nasir/face_recognition_python/master/m1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68741 (67K) [image/jpeg]
# Saving to: ‘m1.jpg’
#
# m1.jpg              100%[===================>]  67.13K  --.-KB/s    in 0.001s
#
# 2022-06-16 07:09:28 (47.3 MB/s) - ‘m1.jpg’ saved [68741/68741]
#
# --2022-06-16 07:09:28--  https://raw.githubusercontent.com/sohaib-nasir/face_recognition_python/master/m2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
img1 = cv2.imread('m1.jpg')
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F9F08082090>

# %%
img2 = cv2.imread('m2.jpg')
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=330x471 at 0x7F9F0807E590>

# %%
img = cv2.imread("m1.jpg")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img)[0]

img2 = cv2.imread("m2.jpg")
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]


result = face_recognition.compare_faces([img_encoding], img_encoding2)
print("Result: ", result)
# Out:
# Result:  [True]

# %%
from google.colab.patches import cv2_imshow
img1 = cv2.imread('m1.jpg')
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F9F1D437190>
